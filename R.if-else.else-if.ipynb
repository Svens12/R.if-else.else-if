# %%
x<- -2
if (x>=0) {
    print('Positive Number')
} else {
    print('Negative Number')
}
print('Énd of Program')
# Out:
# [1] "Negative Number"
# [1] "Énd of Program"

# %%
x<- 3
if (x>=0) {
    print('Positive Number')
} else {
    print('Negative Number')
}
print('Énd of Program')
# Out:
# [1] "Positive Number"
# [1] "Énd of Program"

# %%
x<- 3
if (x>=0) {
    print('Positive Number')
} else if (x<0) {
    print('Negative Number')
} else {
    print('Zero Number')
}
print('Énd of Program')
# Out:
# [1] "Positive Number"
# [1] "Énd of Program"

# %%
x<- -4
if (x>=0) {
    print('Positive Number')
} else if (x<0) {
    print('Negative Number')
} else {
    print('Zero Number')
}
print('Énd of Program')
# Out:
# [1] "Negative Number"
# [1] "Énd of Program"

# %%
x<- 0
if (x>0) {
    print('Positive Number')
} else if (x<0) {
    print('Negative Number')
} else {
    print('Zero Number')
}
print('Énd of Program')
# Out:
# [1] "Zero Number"
# [1] "Énd of Program"
